# %% [markdown]
# >## 1. Importing the needed libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
import warnings 
warnings.filterwarnings('ignore')
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.preprocessing import LabelEncoder, RobustScaler
from sklearn.model_selection import train_test_split
from plotly import graph_objects as go
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_squared_error
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/world-happiness-based-on-cpi-20152020/WorldHappiness_Corruption_2015_2020.csv

# %% [markdown]
# > ## 2. About the dataset
#
# **The goal of the dataset is to find a relationship between some factors like freedom, happiness score, generosity etc. and the CPI score**
# <br/>
# **1. Dataset columns:**
# - gdp_per_capita: The Gross Domestic Product per capita, or GDP per capita, is a measure of a country's economic output that accounts for its number of people. It divides the country's gross domestic product by its total population.
# - dystopia_residual: The Dystopia Residual metric actually is the Dystopia Happiness Score(1.85) + the Residual value or the unexplained value for each country.
# - cpi_score: The Corruption Perceptions Index (CPI) is an index which ranks countries "by their perceived levels of public sector corruption.

# %% [markdown]
# > ## 3. Loading the dataset

# %%
data = pd.read_csv("../input/world-happiness-based-on-cpi-20152020/WorldHappiness_Corruption_2015_2020.csv")
data.head()
# Out:
#        Country  happiness_score  gdp_per_capita    family    health   freedom  \
# 0       Norway            7.537        1.616463  1.533524  0.796667  0.635423
# 1      Denmark            7.522        1.482383  1.551122  0.792566  0.626007
# 2      Iceland            7.504        1.480633  1.610574  0.833552  0.627163
# 3  Switzerland            7.494        1.564980  1.516912  0.858131  0.620071
# 4      Finland            7.469        1.443572  1.540247  0.809158  0.617951
#
#    generosity  government_trust  dystopia_residual continent  Year  \
# 0    0.362012          0.315964           2.277027    Europe  2015
# 1    0.355280          0.400770           2.313707    Europe  2015
# 2    0.475540          0.153527           2.322715    Europe  2015
# 3    0.290549          0.367007           2.276716    Europe  2015
# 4    0.245483          0.382612           2.430182    Europe  2015
#
#    social_support  cpi_score
# 0             0.0         88
# 1             0.0         91
# 2             0.0         79
# 3             0.0         86
# 4             0.0         90

# %% [markdown]
# > ## 4. Exploring the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            792 non-null    object
#  1   happiness_score    792 non-null    float64
#  2   gdp_per_capita     792 non-null    float64
#  3   family             792 non-null    float64
#  4   health             792 non-null    float64
#  5   freedom            792 non-null    float64
#  6   generosity         792 non-null    float64
#  7   government_trust   792 non-null    float64
#  8   dystopia_residual  792 non-null    float64
#  9   continent          792 non-null    object
#  10  Year               792 non-null    int64
#  11  social_support     792 non-null    float64
#  12  cpi_score          792 non-null    int64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 80.6+ KB

# %%
#shape of the dataset
data.shape
# Out:
# (792, 13)

# %% [markdown]
# **- The dataset has 792 records and 13 features**

# %%
#Columns names
data.columns
# Out:
# Index(['Country', 'happiness_score', 'gdp_per_capita', 'family', 'health',
#        'freedom', 'generosity', 'government_trust', 'dystopia_residual',
#        'continent', 'Year', 'social_support', 'cpi_score'],
#       dtype='object')

# %%
#some statistical information about the dataset
data.describe()
# Out:
#        happiness_score  gdp_per_capita      family      health     freedom  \
# count       792.000000      792.000000  792.000000  792.000000  792.000000
# mean          5.473310        0.929217    0.504998    0.648691    0.427016
# std           1.124726        0.385774    0.552736    0.232261    0.148003
# min           2.566900        0.000000    0.000000    0.000000    0.000000
# 25%           4.590750        0.644242    0.000000    0.510070    0.325433
# 50%           5.485500        0.994544    0.000000    0.685397    0.439621
# 75%           6.300500        1.228677    1.040410    0.815641    0.546280
# max           7.808700        2.096000    1.610574    1.141000    0.724000
#
#        generosity  government_trust  dystopia_residual         Year  \
# count  792.000000        792.000000         792.000000   792.000000
# mean     0.212440          0.125720           1.379277  2017.500000
# std      0.121660          0.109032           1.075276     1.708904
# min      0.000000          0.000000           0.000000  2015.000000
# 25%      0.125784          0.052862           0.000000  2016.000000
# 50%      0.197000          0.089000           1.731948  2017.500000
# 75%      0.273250          0.154250           2.236894  2019.000000
# max      0.838075          0.551910           3.602140  2020.000000
#
#        social_support   cpi_score
# count      792.000000  792.000000
# mean         0.609302   44.327020
# std          0.640754   19.508833
# min          0.000000   11.000000
# 25%          0.000000   30.000000
# 50%          0.176214   38.000000
# 75%          1.268250   57.000000
# max          1.644000   91.000000

# %%
#visualizing the correlation
sns.set(rc = {'figure.figsize':(10,6)})
sns.heatmap(data.corr(), annot= True,  cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# >## 5. EDA

# %% [markdown]
# ### 5.1 Countries with the highest CPI score

# %%
sns.set(rc = {'figure.figsize':(8,6)})
sns.barplot(
    y='Country',
    x='cpi_score',
    data=data.nlargest(10, 'cpi_score')
)
# Out:
# <AxesSubplot:xlabel='cpi_score', ylabel='Country'>

# %% [markdown]
# - **As noticed the Denemark has the highest CPI score among the countries**
# <hr>

# %% [markdown]
# ### 5.2 Which country has the highest happiness score?

# %%
sns.set(rc = {'figure.figsize':(8,6)})
sns.barplot(
    x='Country',
    y='happiness_score',
    data=data.nlargest(10, 'happiness_score'), palette='cubehelix'
)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='happiness_score'>

# %% [markdown]
# - **Among all the countries, Finland has the highest happiness score**
# <hr/>

# %% [markdown]
# ### 5.3 Are the happiness score and the CPI score correlated?

# %%
sns.scatterplot(x="happiness_score", y = "cpi_score", data = data)
# Out:
# <AxesSubplot:xlabel='happiness_score', ylabel='cpi_score'>

# %% [markdown]
# - **We can notice that as the happiness score increases, the CPI score also increases.**
# <hr/>

# %% [markdown]
# ### 5.4 Which country has the highest family care rate?

# %%
sns.set(rc = {'figure.figsize':(20,20)})
sns.catplot(x = "Country", y = "family", palette = "summer", data = data.nlargest(4, 'family'))

# %% [markdown]
# - **Iceland has the highest family care rate.**
# <hr/>

# %% [markdown]
# ### 5.5 Does the family care rate contributes in the CPI score?

# %%
sns.set(rc = {'figure.figsize':(8,6)})
sns.scatterplot(x="family", y = "cpi_score", data = data, color = "red")
# Out:
# <AxesSubplot:xlabel='family', ylabel='cpi_score'>

# %% [markdown]
# **Family care rate above zero:**
# - **They are dirctly propotional to each other.**
# <hr/>

# %% [markdown]
# ### 5.6 Which country has the highest gdp_per_capita?

# %%
sns.barplot(y= "gdp_per_capita", x = "Country", data = data.nlargest(8, 'gdp_per_capita'), palette = "coolwarm")
# Out:
# <AxesSubplot:xlabel='Country', ylabel='gdp_per_capita'>

# %% [markdown]
# - **United Arab Emirates has the highest GDP.**
# <hr/>

# %% [markdown]
# ### 5.7 Is there any relationship between the GDP score and the CPI score?

# %%
sns.set(rc = {'figure.figsize':(30,10)})
sns.relplot(data=data, x="gdp_per_capita", y="cpi_score", kind="line", color = "Purple")

# %% [markdown]
# - **The CPI score increases by increasing the GDP score.**
# <hr/>

# %% [markdown]
# ### 5.8 Which country has the highest health rates?

# %%
fig = px.pie(data.nlargest(5, 'health'), values='health', names='Country', title='Countries With The Highest Health Rates', color_discrete_sequence=px.colors.sequential.RdBu)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="31738cca-6768-4ed5-b5ea-df9bf64c3044" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31738cca-6768-4ed5-b5ea-df9bf64c3044")) {                    Plotly.newPlot(                        "31738cca-6768-4ed5-b5ea-df9bf64c3044",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Country=%{label}<br>health=%{value}<extra></extra>","labels":["Singapore","Singapore","Japan","Japan","Spain"],"legendgroup":"","name":"","showlegend":true,"values":[1.141,1.137814283,1.088,1.072881341,1.062],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pa ...

# %% [markdown]
# - **Singapore has the highest health care.**
# <hr/>

# %% [markdown]
# ### 5.9 To what degree does the health rate affect the CPI score?

# %%
sns.relplot(
    data=data,
    x="health", y="cpi_score",
    palette="ch:r=-.5,l=.75"
)

# %% [markdown]
# - **We have the highest CPI score at the highest health rate.**
# <hr/>

# %% [markdown]
# ### 5.10 Which country supports its people freedom?

# %%
fig = px.bar(data.nlargest(5, 'freedom'), x='Country', y='freedom', height=400)
fig.show()
# Out:
# <div>                            <div id="89b81ee9-a981-40fe-8838-278780d742b4" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89b81ee9-a981-40fe-8838-278780d742b4")) {                    Plotly.newPlot(                        "89b81ee9-a981-40fe-8838-278780d742b4",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>freedom=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Uzbekistan","Cambodia","Uzbekistan","Norway","Denmark"],"xaxis":"x","y":[0.724,0.696,0.693270326,0.686,0.683],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[ ...

# %% [markdown]
# - **Uzbekistan has high freedom support rates.**
# <hr/>

# %% [markdown]
# ### 5.11 The relation between the freedom and the CPI score?

# %%
fig = px.scatter(data, x="freedom", y="cpi_score", color="continent",
                 hover_name="Country", log_x=True, size_max=60)
fig.show()
# Out:
# <div>                            <div id="ce52a299-94a0-4b8c-89c5-af0f630e4fb9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce52a299-94a0-4b8c-89c5-af0f630e4fb9")) {                    Plotly.newPlot(                        "ce52a299-94a0-4b8c-89c5-af0f630e4fb9",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>continent=Europe<br>freedom=%{x}<br>cpi_score=%{y}<extra></extra>","hovertext":["Norway","Denmark","Iceland","Switzerland","Finland","Netherlands","Sweden","Austria","Ireland","Germany","Belgium","Luxembourg","United Kingdom","Malta","France","Spain","Slovakia","Poland","Italy","Russia","Lithuania","Latvia","Moldova","Romania","Slovenia","Estonia","Belarus","Serbia","Hungary","Croatia","Kosovo","Montenegro","Greece","Portugal","Bosnia and Herzegovina","Bulgaria","Albania","Ukraine","Switzerland","Iceland","Denmark","Norway","Finland","Netherlands","Sweden","Austria","Luxembourg","Ireland","Belgium","United Kingdom","Germany","France","Spain","Malta","Slovakia","Italy","Moldova","Slovenia","Lithuania","Belarus","Poland","Croatia","Russia","Kosovo","Estonia","Montenegro","Romania","Serbia","Portugal","Latvia","Albania","Bosnia and Herzegovina","Greece","Hungary","Ukraine","Bulgaria","Finland","Denmark","Norway","Iceland","Netherlands","Switzerland","Sweden","Austria","Luxembourg","United Kingdom","Ireland","Germany","Belgium","Malta","France","Spain","Italy","Slovakia","Poland","Lithuania","Slovenia","Kosovo","Romania","Latvia","Estonia","Hungary","Portugal","Russia","Serbia","Moldova","Montenegro","Croatia","Bosnia and Herzegovina","Belarus","Greece","Bulgaria","Albania","Ukraine","Finland","Norway","Denmark","Iceland","Switzerland","Netherlands","Sweden","United Kingdom","Austria","Ireland","Germany","Belgium","Luxembourg","Malta","France","Spain","Slovakia","Poland","Italy","Lithuania","Slovenia","Romania","Latvia","Russia","Estonia","Kosovo","Moldova","Hungary","Belarus","Portugal","Serbia","Greece","Montenegro","Croatia","Bosnia and Herzegovina","Bulgaria","Albania","Ukraine","Denmark","Switzerland","Iceland","Norway","Finland","Netherlands","Sweden","Austria","Germany","Belgium","Ireland","Luxembourg","United Kingdom","Malta","France","Spain","Slovakia","Italy","Moldova","Russia","Poland","Lithuania","Belarus","Slovenia","Latvia","Romania","Estonia","Croatia","Kosovo","Serbia","Bosnia and Herzegovina","Montenegro","Hungary","Portugal","Greece","Albania","Ukraine","Bulgaria","Finland","Denmark","Switzerland","Iceland","Norway","Netherlands","Sweden","Austria","Luxembourg","United Kingdom","Ireland","Germany","Belgium","Malta","France","Spain","Italy","Slovenia","Kosovo","Slovakia","Lithuania","Poland","Romania","Estonia","Hungary","Latvia","Portugal","Serbia","Bosnia and Herzegovina","Moldova","Montenegro","Russia","Belarus","Greece","Croatia","Bulgaria","Albania","Ukraine"],"legendgroup":"Europe","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Europe","orientation":"v","showlegend":true,"x":[0.635422587,0.626006722,0.627162635,0.620070577,0.617950857,0.585384488,0.612924099,0.56776619,0.573110342,0.562511384,0.539770722,0.596627891,0.508190036,0.588767052,0.470222116,0.40878123,0.295817465,0.520342112,0.256450713,0.373783112,0.234231785,0.325707912,0.240729049,0.457003742,0.572575808,0.47913143,0.295400262,0.208715528,0.175863519,0.255772293,0.260287941,0.194989055,0.095731251,0.4984653,0.204403177,0.289231718,0.381498635,0.122974776,0.66557,0.62877,0.64938,0.66973,0.64169,0.61576,0.6598,0.62433,0.61583,0.61777,0.5845,0.59625,0.61477,0.55011,0.45951,0.60365,0.31751,0.26236,0.32818,0.60855,0.21342,0.37938,0.53122,0.25883,0.36679,0.24749,0.44888,0.1826,0.35068,0.20107,0.51469,0.29671,0.35733,0.09245,0.07699,0.32112,0.25123,0.30587,0.596 ...

# %% [markdown]
# - **The higher the freedom rates are, the higher the CPI scores are.**
# <hr/>

# %% [markdown]
# ### 5.12 Which counrty is the most generous one?

# %%
sns.barplot(y= "gdp_per_capita", x = "Country", data = data.nlargest(8, 'generosity'), palette = "coolwarm")
# Out:
# <AxesSubplot:xlabel='Country', ylabel='gdp_per_capita'>

# %% [markdown]
# <hr/>

# %% [markdown]
# ### 5.13 What is the relation between generousity and CPI score?

# %%
fig = px.scatter(data, x="generosity", y="cpi_score", color="continent",
                 hover_name="Country", log_x=True, size_max=60)
fig.show()
# Out:
# <div>                            <div id="41236f03-3b54-4398-81ba-b0a69c5c3994" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Europe","orientation":"v","showlegend":true,"x":[0.362012237,0.355280489,0.475540221,0.290549278,0.245482773,0.47048983,0.385399252,0.316472322,0.427858323,0.33626917,0.231503338,0.283180982,0.492774159,0.574730575,0.129762307,0.190133572,0.136544481,0.158465967,0.172789648,0.052263822,0.010164657,0.153074786,0.208779126,0.133519918,0.242649093,0.098890811,0.155137509,0.220125884,0.078401662,0.248002976,0.319931448,0.197911024,0.0,0.095102713,0.328867495,0.113177694,0.201312944,0.270061463,0.29678,0.4363,0.34139,0.34699,0.23351,0.4761,0.36262,0.33088,0.28034,0.45901,0.2225,0.51912,0.28214,0.12332,0.18227,0.51752,0.16893,0.22823,0.20951,0.25328,0.02641,0.11046,0.16759,0.05444,0.00199,0.2831,0.0868,0.1614,0.13748,0.19231,0.13719,0.18226,0.14272,0.24808,0.0,0.128,0.15275,0.11921,0.153,0.252,0.27 ...

# %% [markdown]
# <hr/>

# %% [markdown]
# > ## 6. Dataset Preprocessing

# %% [markdown]
# ### 6.1 Handling missing values

# %%
#the missing values
data.isnull().head()
# Out:
#    Country  happiness_score  gdp_per_capita  family  health  freedom  \
# 0    False            False           False   False   False    False
# 1    False            False           False   False   False    False
# 2    False            False           False   False   False    False
# 3    False            False           False   False   False    False
# 4    False            False           False   False   False    False
#
#    generosity  government_trust  dystopia_residual  continent   Year  \
# 0       False             False              False      False  False
# 1       False             False              False      False  False
# 2       False             False              False      False  False
# 3       False             False              False      False  False
# 4       False             False              False      False  False
#
#    social_support  cpi_score
# 0           False      False
# 1           False      False
# 2           False      False
# 3           False      False
# 4           False      False

# %%
#the number of the missing values
data.isnull().sum()
# Out:
# Country              0
# happiness_score      0
# gdp_per_capita       0
# family               0
# health               0
# freedom              0
# generosity           0
# government_trust     0
# dystopia_residual    0
# continent            0
# Year                 0
# social_support       0
# cpi_score            0
# dtype: int64

# %% [markdown]
# - **Our dataset has no missing values.**
# <hr/>

# %% [markdown]
# ### 6.2 Handling the outliers

# %% [markdown]
# #### 6.2.1 Happiness score feature

# %%
#Some statistical information about the column
data["happiness_score"].describe()
# Out:
# count    792.000000
# mean       5.473310
# std        1.124726
# min        2.566900
# 25%        4.590750
# 50%        5.485500
# 75%        6.300500
# max        7.808700
# Name: happiness_score, dtype: float64

# %%
sns.set(rc = {'figure.figsize':(8,6)})
sns.scatterplot(x = "happiness_score", y = "cpi_score", data = data, color = "green")
# Out:
# <AxesSubplot:xlabel='happiness_score', ylabel='cpi_score'>

# %% [markdown]
# - **There is no outliers in this column.**
# <hr/>

# %% [markdown]
# #### 6.2.2 gdp_per_capita feature

# %%
#Some statistical information about the column
data["gdp_per_capita"].describe()
# Out:
# count    792.000000
# mean       0.929217
# std        0.385774
# min        0.000000
# 25%        0.644242
# 50%        0.994544
# 75%        1.228677
# max        2.096000
# Name: gdp_per_capita, dtype: float64

# %%
sns.set(rc = {'figure.figsize':(8,6)})
sns.scatterplot(x = "happiness_score", y = "cpi_score", data = data, color = "purple")
# Out:
# <AxesSubplot:xlabel='happiness_score', ylabel='cpi_score'>

# %% [markdown]
# - **There is no outliers in this column.**
# <hr/>

# %% [markdown]
# #### 6.2.3 family feature

# %%
#Some statistical information about the column
data["family"].describe()
# Out:
# count    792.000000
# mean       0.504998
# std        0.552736
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.040410
# max        1.610574
# Name: family, dtype: float64

# %%
sns.set(rc = {'figure.figsize':(8,6)})
sns.scatterplot(x = "family", y = "cpi_score", data = data, color = "pink")
# Out:
# <AxesSubplot:xlabel='family', ylabel='cpi_score'>

# %% [markdown]
# - **There is no outliers**
# <hr/>

# %% [markdown]
# #### 6.2.4 health feature

# %%
#Some statistical information about the column
data["health"].describe()
# Out:
# count    792.000000
# mean       0.648691
# std        0.232261
# min        0.000000
# 25%        0.510070
# 50%        0.685397
# 75%        0.815641
# max        1.141000
# Name: health, dtype: float64

# %%
sns.set(rc = {'figure.figsize':(8,6)})
sns.scatterplot(x = "family", y = "cpi_score", data = data, color = "green")
# Out:
# <AxesSubplot:xlabel='family', ylabel='cpi_score'>

# %% [markdown]
# - **There is no outliers.**
# <hr/>

# %% [markdown]
# #### 6.2.5 generosity feature

# %%
#Some statistical information about the column
data["generosity"].describe()
# Out:
# count    792.000000
# mean       0.212440
# std        0.121660
# min        0.000000
# 25%        0.125784
# 50%        0.197000
# 75%        0.273250
# max        0.838075
# Name: generosity, dtype: float64

# %%
sns.set(rc = {'figure.figsize':(8,6)})
sns.scatterplot(x = "family", y = "cpi_score", data = data, color = "purple")
# Out:
# <AxesSubplot:xlabel='family', ylabel='cpi_score'>

# %% [markdown]
# - **There is no outliers.**
# <hr/>

# %% [markdown]
# #### 6.2.6 government_trust feature

# %%
#Some statistical information about the column
data["government_trust"].describe()
# Out:
# count    792.000000
# mean       0.125720
# std        0.109032
# min        0.000000
# 25%        0.052862
# 50%        0.089000
# 75%        0.154250
# max        0.551910
# Name: government_trust, dtype: float64

# %%
sns.set(rc = {'figure.figsize':(8,6)})
sns.scatterplot(x = "government_trust", y = "cpi_score", data = data, color = "pink")
# Out:
# <AxesSubplot:xlabel='government_trust', ylabel='cpi_score'>

# %% [markdown]
# - **There is no outliers.**
# <hr/>

# %% [markdown]
# #### 6.2.7 dystopia_residual feature

# %%
#Some statistical information about the column
data["dystopia_residual"].describe()
# Out:
# count    792.000000
# mean       1.379277
# std        1.075276
# min        0.000000
# 25%        0.000000
# 50%        1.731948
# 75%        2.236894
# max        3.602140
# Name: dystopia_residual, dtype: float64

# %%
sns.set(rc = {'figure.figsize':(8,6)})
sns.scatterplot(x = "dystopia_residual", y = "cpi_score", data = data, color = "blue")
# Out:
# <AxesSubplot:xlabel='dystopia_residual', ylabel='cpi_score'>

# %% [markdown]
# - **There is no outliers.**
# <hr/>

# %% [markdown]
# #### 6.2.8 year feature

# %%
#Some statistical information about the column
data["Year"].describe()
# Out:
# count     792.000000
# mean     2017.500000
# std         1.708904
# min      2015.000000
# 25%      2016.000000
# 50%      2017.500000
# 75%      2019.000000
# max      2020.000000
# Name: Year, dtype: float64

# %%
sns.set(rc = {'figure.figsize':(8,6)})
sns.scatterplot(x = "Year", y = "cpi_score", data = data, color = "red")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='cpi_score'>

# %% [markdown]
# - **There is no outliers.**
# <hr/>

# %% [markdown]
# #### 6.2.9 social_support feature

# %%
#Some statistical information about the column
data["social_support"].describe()
# Out:
# count    792.000000
# mean       0.609302
# std        0.640754
# min        0.000000
# 25%        0.000000
# 50%        0.176214
# 75%        1.268250
# max        1.644000
# Name: social_support, dtype: float64

# %%
sns.set(rc = {'figure.figsize':(8,6)})
sns.scatterplot(x = "social_support", y = "cpi_score", data = data, color = "black")
# Out:
# <AxesSubplot:xlabel='social_support', ylabel='cpi_score'>

# %% [markdown]
# - **There is no outliers.**
# <hr/>

# %% [markdown]
# ### 6.3 Encoding

# %% [markdown]
# #### 6.3.1 Country feature encoding

# %%
country_le = LabelEncoder()
data["Country"] = country_le.fit_transform(data["Country"])
data.head()
# Out:
#    Country  happiness_score  gdp_per_capita    family    health   freedom  \
# 0       90            7.537        1.616463  1.533524  0.796667  0.635423
# 1       30            7.522        1.482383  1.551122  0.792566  0.626007
# 2       49            7.504        1.480633  1.610574  0.833552  0.627163
# 3      112            7.494        1.564980  1.516912  0.858131  0.620071
# 4       37            7.469        1.443572  1.540247  0.809158  0.617951
#
#    generosity  government_trust  dystopia_residual continent  Year  \
# 0    0.362012          0.315964           2.277027    Europe  2015
# 1    0.355280          0.400770           2.313707    Europe  2015
# 2    0.475540          0.153527           2.322715    Europe  2015
# 3    0.290549          0.367007           2.276716    Europe  2015
# 4    0.245483          0.382612           2.430182    Europe  2015
#
#    social_support  cpi_score
# 0             0.0         88
# 1             0.0         91
# 2             0.0         79
# 3             0.0         86
# 4             0.0         90

# %% [markdown]
# <hr/>

# %% [markdown]
# #### 6.3.2 Continent encoding

# %%
continent_le = LabelEncoder()
data["continent"] = continent_le.fit_transform(data["continent"])
data.head()
# Out:
#    Country  happiness_score  gdp_per_capita    family    health   freedom  \
# 0       90            7.537        1.616463  1.533524  0.796667  0.635423
# 1       30            7.522        1.482383  1.551122  0.792566  0.626007
# 2       49            7.504        1.480633  1.610574  0.833552  0.627163
# 3      112            7.494        1.564980  1.516912  0.858131  0.620071
# 4       37            7.469        1.443572  1.540247  0.809158  0.617951
#
#    generosity  government_trust  dystopia_residual  continent  Year  \
# 0    0.362012          0.315964           2.277027          3  2015
# 1    0.355280          0.400770           2.313707          3  2015
# 2    0.475540          0.153527           2.322715          3  2015
# 3    0.290549          0.367007           2.276716          3  2015
# 4    0.245483          0.382612           2.430182          3  2015
#
#    social_support  cpi_score
# 0             0.0         88
# 1             0.0         91
# 2             0.0         79
# 3             0.0         86
# 4             0.0         90

# %% [markdown]
# <hr/>

# %% [markdown]
# ### 6.4 Features Selection

# %%
x = data.corr()
x.style.background_gradient(cmap = "Set3")
# Out:
# <style type="text/css">
# #T_fbc73_row0_col0, #T_fbc73_row1_col1, #T_fbc73_row2_col2, #T_fbc73_row3_col3, #T_fbc73_row4_col4, #T_fbc73_row5_col5, #T_fbc73_row6_col6, #T_fbc73_row7_col7, #T_fbc73_row8_col8, #T_fbc73_row9_col9, #T_fbc73_row10_col10, #T_fbc73_row11_col11, #T_fbc73_row12_col12 {
#   background-color: #ffed6f;
#   color: #000000;
# }
# #T_fbc73_row0_col1, #T_fbc73_row0_col2, #T_fbc73_row0_col4, #T_fbc73_row0_col7, #T_fbc73_row0_col9, #T_fbc73_row0_col12, #T_fbc73_row3_col4, #T_fbc73_row3_col5, #T_fbc73_row3_col10, #T_fbc73_row3_col11, #T_fbc73_row4_col0, #T_fbc73_row6_col2, #T_fbc73_row6_col4, #T_fbc73_row6_col9, #T_fbc73_row8_col2, #T_fbc73_row8_col4, #T_fbc73_row8_col5, #T_fbc73_row8_col12, #T_fbc73_row9_col0, #T_fbc73_row9_col7, #T_fbc73_row10_col1, #T_fbc73_row10_col2, #T_fbc73_row10_col5, #T_fbc73_row10_col7, #T_fbc73_row10_col12, #T_fbc73_row11_col3, #T_fbc73_row11_col6, #T_fbc73_row11_col7, #T_fbc73_row11_col8 {
#   background-color: #8dd3c7;
#   color: #000000;
# }
# #T_fbc73_row0_col3, #T_fbc73_row0_col11, #T_fbc73_row1_col7, #T_fbc73_row2_col8, #T_fbc73_row2_col9, #T_fbc73_row4_col3, #T_fbc73_row5_col3, #T_fbc73_row5_col4, #T_fbc73_row5_col6, #T_fbc73_row5_col7, #T_fbc73_row5_col12, #T_fbc73_row6_col8, #T_fbc73_row7_col1, #T_fbc73_row7_col5, #T_fbc73_row7_col8, #T_fbc73_row7_col11, #T_fbc73_row9_col8, #T_fbc73_row10_col8, #T_fbc73_row12_col5 {
#   background-color: #fdb462;
#   color: #000000;
# }
# #T_fbc73_row0_col5, #T_fbc73_row1_col0, #T_fbc73_row2_col0, #T_fbc73_row2_col6, #T_fbc73_row3_col0, #T_fbc73_row3_col1, #T_fbc73_row3_col7, #T_fbc73_row3_col12, #T_fbc73_row4_col6, #T_fbc73_row6_col1, #T_fbc73_row7_col0, #T_fbc73_row7_col9, #T_fbc73_row8_col0, #T_fbc73_row8_col7, #T_fbc73_row8_col11, #T_fbc73_row9_col6, #T_fbc73_row10_col0, #T_fbc73_row10_col3, #T_fbc73_row10_col4, #T_fbc73_row10_col6, #T_fbc73_row10_col9, #T_fbc73_row11_col0, #T_fbc73_row11_col2, #T_fbc73_row11_col12, #T_fbc73_row12_col0 {
#   background-color: #ffffb3;
#   color: #000000;
# }
# #T_fbc73_row0_col6, #T_fbc73_row1_col6, #T_fbc73_row4_col7, #T_fbc73_row5_col9, #T_fbc73_row6_col5, #T_fbc73_row6_col7, #T_fbc73_row6_col10, #T_fbc73_row8_col6, #T_fbc73_row9_col12, #T_fbc73_row12_col6, #T_fbc73_row12_col9 {
#   background-color: #fb8072;
#   color: #f1f1f1;
# }
# #T_fbc73_row0_col8, #T_fbc73_row0_col10, #T_fbc73_row1_col10, #T_fbc73_row2_col5, #T_fbc73_row2_col7, #T_fbc73_row2_col10, #T_fbc73_row3_col6, #T_fbc73_row4_col5, #T_fbc73_row4_col8, #T_fbc73_row4_col10, #T_fbc73_row5_col2, #T_fbc73_row5_col8, #T_fbc73_row5_col10, #T_fbc73_row6_col11, #T_fbc73_row7_col2, #T_fbc73_row7_col4, #T_fbc73_row7_col6, #T_fbc73_row7_col10, #T_fbc73_row8_col10, #T_fbc73_row9_col2, #T_fbc73_row9_col10, #T_fbc73_row11_col4, #T_fbc73_row12_col8, #T_fbc73_row12_col10 {
#   background-color: #80b1d3;
#   color: #f1f1f1;
# }
# #T_fbc73_row1_col2, #T_fbc73_row1_col4, #T_fbc73_row2_col1, #T_fbc73_row2_col4, #T_fbc73_row3_col8, #T_fbc73_row4_col1, #T_fbc73_row4_col2, #T_fbc73_row8_col3 {
#   background-color: #bc80bd;
#   color: #f1f1f1;
# }
# #T_fbc73_row1_col3, #T_fbc73_row1_col5, #T_fbc73_row1_col8, #T_fbc73_row1_col11, #T_fbc73_row2_col3, #T_fbc73_row2_col11, #T_fbc73_row4_col9, #T_fbc73_row5_col1, #T_fbc73_row5_col11, #T_fbc73_row7_col3, #T_fbc73_row9_col1, #T_fbc73_row9_col3, #T_fbc73_row9_col4, #T_fbc73_row9_col11, #T_fbc73_row12_col3, #T_fbc73_row12_col11 {
#   background-color: #b3de69;
#   color: #000000;
# }
# #T_fbc73_row1_col9, #T_fbc73_row4_col11, #T_fbc73_row4_col12, #T_fbc73_row6_col3, #T_fbc73_row7_col12, #T_fbc73_row11_col10, #T_fbc73_row12_col7 {
#   background-color: #fccde5;
#   color: #000000;
# }
# #T_fbc73_row1_col12, #T_fbc73_row2_col12, #T_fbc73_row10_col11, #T_fbc73_row12_col1, #T_fbc73_row12_col2, #T_fbc73_row12_col4 {
#   background-color: #d9d9d9;
#   color: #000000;
# }
# #T_fbc73_row3_col2, #T_fbc73_row3_col9, #T_fbc73_row5_col0, #T_fbc73_row6_col0, #T_fbc73_row6_col12, #T_fbc73_row8_col1, #T_fbc73_row8_col9, #T_fbc73_row9_col5, #T_fbc73_row11_col1, #T_fbc73_row11_col5, #T_fbc73_row11_col9 {
#   background-color: #bebada;
#   color: #000000;
# }
# </style>
# <table id="T_fbc73_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Country</th>
#       <th class="col_heading level0 col1" >happiness_score</th>
#       <th class="col_heading level0 col2" >gdp_per_capita</th>
#       <th class="col_heading level0 col3" >family</th>
#       <th class="col_heading level0 col4" >health</th>
#       <th class="col_heading level0 col5" >freedom</th>
#       <th class="col_heading level0 col6" >generosity</th>
#       <th class="col_heading level0 col7" >government_trust</th>
#       <th class="col_heading level0 col8" >dystopia_residual</th>
#       <th class="col_heading level0 col9" >continent</th>
#       <th class="col_heading level0 col10" >Year</th>
#       <th class="col_heading level0 col11" >social_support</th>
#       <th class="col_heading level0 col12" >cpi_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fbc73_level0_row0" class="row_heading level0 row0" >Country</th>
#       <td id="T_fbc73_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_fbc73_row0_col1" class="data row0 col1" >-0.002398</td>
#       <td id="T_fbc73_row0_col2" class="data row0 col2" >-0.018835</td>
#       <td id="T_fbc73_row0_col3" class="data row0 col3" >0.037935</td>
#       <td id="T_fbc73_row0_col4" class="data row0 col4" >-0.040388</td>
#       <td id="T_fbc73_row0_col5" class="data row0 col5" >0.086367</td>
#       <td id="T_fbc73_row0_col6" class="data row0 col6" >0.118777</td>
#       <td id="T_fbc73_row0_col7" class="data row0 col7" >0.046771</td>
#       <td id="T_fbc73_row0_col8" class="data row0 col8" >-0.032824</td>
#       <td id="T_fbc73_row0_col9" class="data row0 col9" >-0.126724</td>
#       <td id="T_fbc73_row0_col10" class="data row0 col10" >0.000000</td>
#       <td id="T_fbc73_row0_col11" class="data row0 col11" >0.030144</td>
#       <td id="T_fbc73_row0_col12" class="data row0 col12" >-0.008631</td>
#     </tr>
#     <tr>
#       <th id="T_fbc73_level0_row1" class="row_heading level0 row1" >happiness_score</th>
#       <td id="T_fbc73_row1_col0" class="data row1 col0" >-0.002398</td>
#       <td id="T_fbc73_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_fbc73_row1_col2" class="data row1 col2" >0.793267</td>
#       <td id="T_fbc73_row1_col3" class="data row1 col3" >0.154946</td>
#       <td id="T_fbc73_row1_col4" class="data row1 col4" >0.753534</td>
#       <td id="T_fbc73_row1_col5" class="data row1 col5" >0.544284</td>
#       <td id="T_fbc73_row1_col6" class="data row1 col6" >0.155419</td>
#       <td id="T_fbc73_row1_col7" class="data row1 col7" >0.455477</td>
#       <td id="T_fbc73_row1_col8" class="data row1 col8" >0.174161</td>
#       <td id="T_fbc73_row1_col9" class="data row1 col9" >0.542881</td>
#       <td id="T_fbc73_row1_col10" class="data row1 col10" >0.023495</td>
#       <td id="T_fbc73_row1_col11" class="data row1 col11" >0.192633</td>
#       <td id="T_fbc73_row1_col12" class="data row1 col12" >0.693001</td>
#     </tr>
#     <tr>
#       <th id="T_fbc73_level0_row2" class="row_heading level0 row2" >gdp_per_capita</th>
#       <td id="T_fbc73_row2_col0" class="data row2 col0" >-0.018835</td>
#       <td id="T_fbc73_row2_col1" class="data row2 col1" >0.793267</td>
#       <td id="T_fbc73_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_fbc73_row2_col3" class="data row2 col3" >0.218191</td>
#       <td id="T_fbc73_row2_col4" class="data row2 col4" >0.774980</td>
#       <td id="T_fbc73_row2_col5" class="data row2 col5" >0.340260</td>
#       <td id="T_fbc73_row2_col6" class="data row2 col6" >-0.018355</td>
#       <td id="T_fbc73_row2_col7" class="data row2 col7" >0.359068</td>
#       <td id="T_fbc73_row2_col8" class="data row2 col8" >0.042710</td>
#       <td id="T_fbc73_row2_col9" class="data row2 col9" >0.389292</td>
#       <td id="T_fbc73_row2_col10" class="data row2 col10" >-0.035782</td>
#       <td id="T_fbc73_row2_col11" class="data row2 col11" >0.111701</td>
#       <td id="T_fbc73_row2_col12" class=

# %% [markdown]
# - **From the previous table we can drop Country, continent and Year features because they aren't correlated with the target.**

# %%
data = data.drop(["Country", "continent", "Year"], axis = 1)
data.head()
# Out:
#    happiness_score  gdp_per_capita    family    health   freedom  generosity  \
# 0            7.537        1.616463  1.533524  0.796667  0.635423    0.362012
# 1            7.522        1.482383  1.551122  0.792566  0.626007    0.355280
# 2            7.504        1.480633  1.610574  0.833552  0.627163    0.475540
# 3            7.494        1.564980  1.516912  0.858131  0.620071    0.290549
# 4            7.469        1.443572  1.540247  0.809158  0.617951    0.245483
#
#    government_trust  dystopia_residual  social_support  cpi_score
# 0          0.315964           2.277027             0.0         88
# 1          0.400770           2.313707             0.0         91
# 2          0.153527           2.322715             0.0         79
# 3          0.367007           2.276716             0.0         86
# 4          0.382612           2.430182             0.0         90

# %% [markdown]
# <hr/>

# %% [markdown]
# ### 6.5 Feature Scaling

# %%
#Making a copy from the column that needs to be scaled
scale = data.iloc[:, :-1]
scale.reset_index()
scaler = RobustScaler()
scale = scaler.fit_transform(scale.to_numpy())
scale = pd.DataFrame (scale, columns = ["happiness_score", "gdp_per_capita", "family", "health", "freedom", "generosity", "government_trust", "dystopia_residual", "social_support"])
scale.head()
# Out:
#    happiness_score  gdp_per_capita    family    health   freedom  generosity  \
# 0         1.199883        1.064137  1.473961  0.364135  0.886594    1.118986
# 1         1.191110        0.834719  1.490875  0.350714  0.843959    1.073337
# 2         1.180582        0.831724  1.548019  0.484845  0.849193    1.888846
# 3         1.174733        0.976046  1.457994  0.565282  0.817080    0.634379
# 4         1.160111        0.768311  1.480423  0.405013  0.807482    0.328773
#
#    government_trust  dystopia_residual  social_support
# 0          2.238578           0.243677       -0.138943
# 1          3.075035           0.260075       -0.138943
# 2          0.636435           0.264102       -0.138943
# 3          2.742027           0.243538       -0.138943
# 4          2.895934           0.312144       -0.138943

# %%
data.iloc[:, : -1] = scale
data.head()
# Out:
#    happiness_score  gdp_per_capita    family    health   freedom  generosity  \
# 0         1.199883        1.064137  1.473961  0.364135  0.886594    1.118986
# 1         1.191110        0.834719  1.490875  0.350714  0.843959    1.073337
# 2         1.180582        0.831724  1.548019  0.484845  0.849193    1.888846
# 3         1.174733        0.976046  1.457994  0.565282  0.817080    0.634379
# 4         1.160111        0.768311  1.480423  0.405013  0.807482    0.328773
#
#    government_trust  dystopia_residual  social_support  cpi_score
# 0          2.238578           0.243677       -0.138943         88
# 1          3.075035           0.260075       -0.138943         91
# 2          0.636435           0.264102       -0.138943         79
# 3          2.742027           0.243538       -0.138943         86
# 4          2.895934           0.312144       -0.138943         90

# %% [markdown]
# <hr/>

# %% [markdown]
# > ## 7.Train Test Split

# %%
x = data.drop(['cpi_score'], axis= 1).values 
y = data["cpi_score"].values

# %%
x.shape
# Out:
# (792, 9)

# %%
y.shape
# Out:
# (792,)

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y, test_size= 0.20, random_state =42,shuffle=True)

# %%
x_train.shape
# Out:
# (633, 9)

# %%
x_test.shape
# Out:
# (159, 9)

# %% [markdown]
# <hr/>

# %% [markdown]
# > ## 8. Modeling

# %% [markdown]
# ### 8.1 First model with 2 hidden layers

# %%
model1 = Sequential()
# Out:
# 2022-10-17 20:02:09.950442: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
#input layer
model1.add(Dense(20, input_shape = (9,), activation = 'relu'))

# %%
#hidden layers
model1.add(Dense(10, activation = "relu"))
model1.add(Dense(8, activation = "relu"))

# %%
#output layer
model1.add(Dense(1))

# %%
model1.compile(optimizer = "Adam", loss = "mse", metrics = "mae")

# %%
#training
model1.fit(x = x_train, y = y_train, validation_data = (x_test, y_test), batch_size = 200, epochs = 20)
# Out:
# 2022-10-17 20:02:10.814120: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/20
# 4/4 [==============================] - 1s 76ms/step - loss: 2385.2163 - mae: 44.7324 - val_loss: 2118.2095 - val_mae: 41.9926
# Epoch 2/20
# 4/4 [==============================] - 0s 14ms/step - loss: 2378.9653 - mae: 44.6721 - val_loss: 2112.3921 - val_mae: 41.9337
# Epoch 3/20
# 4/4 [==============================] - 0s 14ms/step - loss: 2372.4106 - mae: 44.6087 - val_loss: 2106.0657 - val_mae: 41.8705
# Epoch 4/20
# 4/4 [==============================] - 0s 15ms/step - loss: 2364.9546 - mae: 44.5383 - val_loss: 2098.9880 - val_mae: 41.8017
# Epoch 5/20
# 4/4 [==============================] - 0s 15ms/step - loss: 2356.9922 - mae: 44.4633 - val_loss: 2091.3267 - val_mae: 41.7280
# Epoch 6/20
# 4/4 [==============================] - 0s 19ms/step - loss: 2348.0874 - mae: 44.3814 - val_loss: 2083.3005 - val_mae: 41.6494
# Epoch 7/20
# 4/4 [==============================] - 0s 15ms/step - loss: 2339.0327 - mae: 44.2960 - val_loss: 2074.6077 - val_mae: 41.5644
# Epoch 8/20
# 4/4 [==============================] - 0s 15ms/step - loss: 2328.9810 - mae: 44.2026 - val_loss: 2065.2224 - val_mae: 41.4724
# Epoch 9/20
# 4/4 [==============================] - 0s 14ms/step - loss: 2318.2456 - mae: 44.1029 - val_loss: 2055.1155 - val_mae: 41.3735
# Epoch 10/20
# 4/4 [==============================] - 0s 14ms/step - loss: 2306.6382 - mae: 43.9951 - val_loss: 2044.1486 - val_mae: 41.2663
# Epoch 11/20
# 4/4 [==============================] - 0s 16ms/step - loss: 2294.4626 - mae: 43.8793 - val_loss: 2032.2775 - val_mae: 41.1499
# Epoch 12/20
# 4/4 [==============================] - 0s 14ms/step - loss: 2280.5330 - mae: 43.7509 - val_loss: 2019.7223 - val_mae: 41.0259
# Epoch 13/20
# 4/4 [==============================] - 0s 14ms/step - loss: 2266.0396 - mae: 43.6150 - val_loss: 2006.2075 - val_mae: 40.8923
# Epoch 14/20
# 4/4 [==============================] - 0s 14ms/step - loss: 2250.3455 - mae: 43.4672 - val_loss: 1991.5063 - val_mae: 40.7467
# Epoch 15/20
# 4/4 [==============================] - 0s 14ms/step - loss: 2233.5500 - mae: 43.3082 - val_loss: 1975.7030 - val_mae: 40.5889
# Epoch 16/20
# 4/4 [==============================] - 0s 15ms/step - loss: 2215.2866 - mae: 43.1353 - val_loss: 1959.0322 - val_mae: 40.4209
# Epoch 17/20
# 4/4 [==============================] - 0s 14ms/step - loss: 2195.9404 - mae: 42.9504 - val_loss: 1941.1580 - val_mae: 40.2394
# Epoch 18/20
# 4/4 [==============================] - 0s 15ms/step - loss: 2175.3787 - mae: 42.7492 - val_loss: 1921.6315 - val_mae: 40.0407
# Epoch 19/20
# 4/4 [==============================] - 0s 15ms/step - loss: 2152.5056 - mae: 42.5302 - val_loss: 1900.7616 - val_mae: 39.8264
# Epoch 20/20
# 4/4 [==============================] - 0s 15ms/step - loss: 2128.5330 - mae: 42.2951 - val_loss: 1878.1115 - val_mae: 39.5927

# %%
#testing
model1_pred = model1.predict(x_test)

# %% [markdown]
# ### 8.1.1 First model evalaution

# %%
#mean absolute error
mae1 = mean_absolute_error(y_test, model1_pred)
mae1
# Out:
# 39.59271679059515

# %%
#mean squared error
mse1 = mean_squared_error(y_test, model1_pred)
mse1
# Out:
# 1878.11131084007

# %%
plt.scatter(y_test, model1_pred)
plt.plot(y_test, y_test, "r")

# %%
model1.evaluate(x_test, y_test)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 1878.1112 - mae: 39.5927
# [1878.1112060546875, 39.592716217041016]

# %% [markdown]
# <hr/>

# %% [markdown]
# ### 8.2 Second model with 4 hidden layers

# %%
model2 = Sequential()

# %%
#input layer
model2.add(Dense(7, input_shape = (9,), activation = 'relu'))

# %%
#hidden layers
model2.add(Dense(7, activation = "linear"))
model2.add(Dense(5, activation = "linear"))
model2.add(Dense(7, activation = "relu"))
model2.add(Dense(5, activation = "relu"))

# %%
#output layer
model2.add(Dense(1))

# %%
model2.compile(optimizer = "Adam", loss = "mse", metrics = "mae")

# %%
#training
model2.fit(x = x_train, y = y_train, validation_data = (x_test, y_test), batch_size = 200, epochs = 40)
# Out:
# Epoch 1/40
# 4/4 [==============================] - 1s 70ms/step - loss: 2403.5020 - mae: 44.9658 - val_loss: 2138.5854 - val_mae: 42.2483
# Epoch 2/40
# 4/4 [==============================] - 0s 14ms/step - loss: 2398.6797 - mae: 44.9089 - val_loss: 2134.1982 - val_mae: 42.1962
# Epoch 3/40
# 4/4 [==============================] - 0s 15ms/step - loss: 2394.1033 - mae: 44.8569 - val_loss: 2130.0640 - val_mae: 42.1485
# Epoch 4/40
# 4/4 [==============================] - 0s 15ms/step - loss: 2389.6917 - mae: 44.8101 - val_loss: 2126.1799 - val_mae: 42.1060
# Epoch 5/40
# 4/4 [==============================] - 0s 15ms/step - loss: 2385.5171 - mae: 44.7677 - val_loss: 2122.5491 - val_mae: 42.0687
# Epoch 6/40
# 4/4 [==============================] - 0s 14ms/step - loss: 2381.3867 - mae: 44.7280 - val_loss: 2118.9336 - val_mae: 42.0327
# Epoch 7/40
# 4/4 [==============================] - 0s 15ms/step - loss: 2377.1982 - mae: 44.6886 - val_loss: 2114.9985 - val_mae: 41.9948
# Epoch 8/40
# 4/4 [==============================] - 0s 15ms/step - loss: 2372.5117 - mae: 44.6459 - val_loss: 2110.7087 - val_mae: 41.9537
# Epoch 9/40
# 4/4 [==============================] - 0s 15ms/step - loss: 2367.3926 - mae: 44.5991 - val_loss: 2105.9148 - val_mae: 41.9080
# Epoch 10/40
# 4/4 [==============================] - 0s 15ms/step - loss: 2361.6311 - mae: 44.5471 - val_loss: 2100.5779 - val_mae: 41.8574
# Epoch 11/40
# 4/4 [==============================] - 0s 15ms/step - loss: 2355.0637 - mae: 44.4875 - val_loss: 2094.6086 - val_mae: 41.8011
# Epoch 12/40
# 4/4 [==============================] - 0s 14ms/step - loss: 2347.7949 - mae: 44.4216 - val_loss: 2087.9006 - val_mae: 41.7376
# Epoch 13/40
# 4/4 [==============================] - 0s 14ms/step - loss: 2339.5222 - mae: 44.3465 - val_loss: 2080.2295 - val_mae: 41.6647
# Epoch 14/40
# 4/4 [==============================] - 0s 15ms/step - loss: 2330.0442 - mae: 44.2606 - val_loss: 2071.4839 - val_mae: 41.5809
# Epoch 15/40
# 4/4 [==============================] - 0s 14ms/step - loss: 2319.2761 - mae: 44.1621 - val_loss: 2061.1985 - val_mae: 41.4817
# Epoch 16/40
# 4/4 [==============================] - 0s 14ms/step - loss: 2306.7930 - mae: 44.0478 - val_loss: 2049.0945 - val_mae: 41.3641
# Epoch 17/40
# 4/4 [==============================] - 0s 14ms/step - loss: 2291.9932 - mae: 43.9132 - val_loss: 2035.0522 - val_mae: 41.2268
# Epoch 18/40
# 4/4 [==============================] - 0s 15ms/step - loss: 2275.2883 - mae: 43.7583 - val_loss: 2018.9572 - val_mae: 41.0683
# Epoch 19/40
# 4/4 [==============================] - 0s 14ms/step - loss: 2256.6951 - mae: 43.5832 - val_loss: 2000.4379 - val_mae: 40.8831
# Epoch 20/40
# 4/4 [==============================] - 0s 15ms/step - loss: 2234.8364 - mae: 43.3773 - val_loss: 1979.3373 - val_mae: 40.6683
# Epoch 21/40
# 4/4 [==============================] - 0s 15ms/step - loss: 2209.7351 - mae: 43.1373 - val_loss: 1955.0796 - val_mae: 40.4192
# Epoch 22/40
# 4/4 [==============================] - 0s 14ms/step - loss: 2181.2722 - mae: 42.8610 - val_loss: 1926.7343 - val_mae: 40.1255
# Epoch 23/40
# 4/4 [==============================] - 0s 18ms/step - loss: 2147.1445 - mae: 42.5283 - val_loss: 1893.5038 - val_mae: 39.7804
# Epoch 24/40
# 4/4 [==============================] - 0s 23ms/step - loss: 2108.1287 - mae: 42.1437 - val_loss: 1855.3689 - val_mae: 39.3804
# Epoch 25/40
# 4/4 [==============================] - 0s 14ms/step - loss: 2063.0278 - mae: 41.6944 - val_loss: 1812.5767 - val_mae: 38.9260
# Epoch 26/40
# 4/4 [==============================] - 0s 16ms/step - loss: 2013.7549 - mae: 41.1912 - val_loss: 1764.7427 - val_mae: 38.4113
# Epoch 27/40
# 4/4 [==============================] - 0s 15ms/step - loss: 1958.0071 - mae: 40.6201 - val_loss: 1712.4065 - val_mae: 37.8377
# Epoch 28/40
# 4/4 [==============================] - 0s 15ms/step - loss: 1896.7804 - mae: 39.9796 - val_loss: 1655.0242 - val_mae: 37.1950
# Epoch 29/40
# 4/4 [==============================] - 0s 14ms/step - loss: 1830.4501 - mae: 39.2683 - val_loss: 1592.2013 - val_mae: 36.4748
# Epoch 30/40
# 4/4 [==============================] - 0s 14ms/step - loss: 1757.8484 - mae: 38.4626 - val_loss: 1523.7365 - val_mae: 35.6684
# Epoch 31/40
# 4/4 [==============================] - 0s 14ms/step - loss: 1678.4945 - mae: 37.5692 - val_loss: 1451.0682 - val_mae: 34.7864
# Epoch 32/40
# 4/4 [==============================] - 0s 13ms/step - loss: 1596.2994 - mae: 36.6116 - val_loss: 1373.2297 - val_mae: 33.8104
# Epoch 33/40
# 4/4 [==============================] - 0s 15ms/step - loss: 1504.8444 - mae: 35.5309 - val_loss: 1291.7316 - val_mae: 32.7491
# Epoch 34/40
# 4/4 [==============================] - 0s 14ms/step - loss: 1411.0918 - mae: 34.3675 - val_loss: 1205.3931 - val_mae: 31.5772
# Epoch 35/40
# 4/4 [==============================] - 0s 14ms/step - loss: 1311.7615 - mae: 33.0936 - val_loss: 1114.0990 - val_mae: 30.2933
# Epoch 36/40
# 4/4 [==============================] - 0s 14ms/step - loss: 1207.6835 - mae: 31.7187 - val_loss: 1019.6656 - val_mae: 28.9060
# Epoch 37/40
# 4/4 [==============================] - 0s 15ms/step - loss: 1100.7926 - mae: 30.2462 - val_loss: 923.7105 - val_mae: 27.4006
# Epoch 38/40
# 4/4 [==============================] - 0s 14ms/step - loss: 991.3824 - mae: 28.6506 - val_loss: 827.6727 - val_mae: 25.7759
# Epoch 39/40
# 4/4 [==============================] - 0s 14ms/step - loss: 883.6100 - mae: 26.9665 - val_loss: 733.3688 - val_mae: 24.0564
# Epoch 40/40
# 4/4 [==============================] - 0s 15ms/step - loss: 780.5328 - mae: 25.2278 - val_loss: 641.5671 - val_mae: 22.2266

# %%
#testing
model2_pred = model2.predict(x_test)

# %% [markdown]
# #### 8.2.1 Second model evaluation

# %%
#mean absolute error
mae2 = mean_absolute_error(y_test, model2_pred)
mae2
# Out:
# 22.226636376770788

# %% [markdown]
# - **The error in model2 is less than the error in model1**

# %%
#mean squared error
mse2 = mean_squared_error(y_test, model2_pred)
mse2
# Out:
# 641.5671918772641

# %%
plt.scatter(y_test, model2_pred)
plt.plot(y_test, y_test, "r")

# %% [markdown]
# - **Much better than model1**

# %%
model2.evaluate(x_test, y_test)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 641.5672 - mae: 22.2266
# [641.5671997070312, 22.22663688659668]

# %% [markdown]
# <hr/>

# %% [markdown]
# ### 8.3 Third model with 7 hidden layers and 60 epochs

# %%
model3 = Sequential()

# %%
#input layer
model3.add(Dense(9, input_shape = (9,), activation = 'relu'))

# %%
#hidden layers
model3.add(Dense(8, activation = "linear"))
model3.add(Dense(7, activation = "linear"))
model3.add(Dense(6, activation = "linear"))
model3.add(Dense(5, activation = "linear"))
model3.add(Dense(4, activation = "linear"))
model3.add(Dense(3, activation = "linear"))
model3.add(Dense(2, activation = "linear"))

# %%
#output layer
model3.add(Dense(1))

# %%
model3.compile(optimizer = "Adam", loss = "mse", metrics = "mae")

# %%
#training
model3.fit(x = x_train, y = y_train, validation_data = (x_test, y_test), batch_size = 200, epochs = 60)
# Out:
# Epoch 1/60
# 4/4 [==============================] - 1s 78ms/step - loss: 2390.6836 - mae: 44.7177 - val_loss: 2114.6458 - val_mae: 41.8761
# Epoch 2/60
# 4/4 [==============================] - 0s 15ms/step - loss: 2372.3806 - mae: 44.5291 - val_loss: 2096.8420 - val_mae: 41.6808
# Epoch 3/60
# 4/4 [==============================] - 0s 16ms/step - loss: 2353.2825 - mae: 44.3286 - val_loss: 2077.5374 - val_mae: 41.4663
# Epoch 4/60
# 4/4 [==============================] - 0s 15ms/step - loss: 2332.2263 - mae: 44.1062 - val_loss: 2056.0112 - val_mae: 41.2241
# Epoch 5/60
# 4/4 [==============================] - 0s 15ms/step - loss: 2308.3992 - mae: 43.8521 - val_loss: 2031.4316 - val_mae: 40.9453
# Epoch 6/60
# 4/4 [==============================] - 0s 15ms/step - loss: 2281.6575 - mae: 43.5605 - val_loss: 2002.7799 - val_mae: 40.6181
# Epoch 7/60
# 4/4 [==============================] - 0s 15ms/step - loss: 2249.8770 - mae: 43.2175 - val_loss: 1969.1823 - val_mae: 40.2312
# Epoch 8/60
# 4/4 [==============================] - 0s 17ms/step - loss: 2212.1321 - mae: 42.8077 - val_loss: 1929.5258 - val_mae: 39.7697
# Epoch 9/60
# 4/4 [==============================] - 0s 16ms/step - loss: 2168.6138 - mae: 42.3177 - val_loss: 1882.1056 - val_mae: 39.2143
# Epoch 10/60
# 4/4 [==============================] - 0s 17ms/step - loss: 2115.3618 - mae: 41.7268 - val_loss: 1826.2590 - val_mae: 38.5490
# Epoch 11/60
# 4/4 [==============================] - 0s 15ms/step - loss: 2053.3857 - mae: 41.0218 - val_loss: 1760.1987 - val_mae: 37.7460
# Epoch 12/60
# 4/4 [==============================] - 0s 16ms/step - loss: 1978.7395 - mae: 40.1614 - val_loss: 1681.6202 - val_mae: 36.7718
# Epoch 13/60
# 4/4 [==============================] - 0s 15ms/step - loss: 1889.5963 - mae: 39.1153 - val_loss: 1588.3778 - val_mae: 35.5864
# Epoch 14/60
# Epoch 55/60
# 4/4 [==============================] - 0s 15ms/step - loss: 123.5663 - mae: 8.6206 - val_loss: 111.7757 - val_mae: 8.6938
# Epoch 56/60
# 4/4 [==============================] - 0s 16ms/step - loss: 122.9397 - mae: 8.6056 - val_loss: 111.2805 - val_mae: 8.6769
# Epoch 57/60
# 4/4 [==============================] - 0s 15ms/step - loss: 122.3760 - mae: 8.5935 - val_loss: 110.6277 - val_mae: 8.6582
# Epoch 58/60
# 4/4 [==============================] - 0s 15ms/step - loss: 121.9472 - mae: 8.5862 - val_loss: 110.2347 - val_mae: 8.6432
# Epoch 59/60
# 4/4 [==============================] - 0s 16ms/step - loss: 121.3430 - mae: 8.5664 - val_loss: 110.0013 - val_mae: 8.6289
# Epoch 60/60
# 4/4 [==============================] - 0s 15ms/step - loss: 120.7705 - mae: 8.5441 - val_loss: 109.7626 - val_mae: 8.6122

# %%
#testing
model3_pred = model3.predict(x_test)

# %% [markdown]
# #### 8.3.1 Model Evaluation

# %%
#mean absolute error
mae3 = mean_absolute_error(y_test, model3_pred)
mae3
# Out:
# 8.61223198032979

# %% [markdown]
# - **Much better than model2!**

# %%
#mean squared error
mse3 = mean_squared_error(y_test, model3_pred)
mse3
# Out:
# 109.76259594571742

# %%
plt.scatter(y_test, model3_pred)
plt.plot(y_test, y_test, "r")

# %%
model3.evaluate(x_test, y_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 109.7626 - mae: 8.6122
# [109.76260375976562, 8.612232208251953]

# %% [markdown]
# <hr/>

# %% [markdown]
# ### 8.4 Forth model

# %%
model4 = Sequential()

# %%
#input layer
model4.add(Dense(15, input_shape = (9,), activation = 'relu'))

# %%
#hidden layers
model4.add(Dense(14, activation = "linear"))
model4.add(Dense(13, activation = "linear"))
model4.add(Dense(12, activation = "linear"))
model4.add(Dense(11, activation = "linear"))
model4.add(Dense(10, activation = "linear"))
model4.add(Dense(9, activation = "linear"))
model4.add(Dense(8, activation = "linear"))
model4.add(Dense(7, activation = "linear"))
model4.add(Dense(6, activation = "linear"))
model4.add(Dense(5, activation = "linear"))
model4.add(Dense(4, activation = "linear"))
model4.add(Dense(3, activation = "linear"))
model4.add(Dense(2, activation = "linear"))

# %%
#output layer
model4.add(Dense(1))

# %%
model4.compile(optimizer = "Adam", loss = "mse", metrics = "mae")

# %%
#training
model4.fit(x = x_train, y = y_train, validation_data = (x_test, y_test), batch_size = 200, epochs = 80)
# Out:
# Epoch 1/80
# 4/4 [==============================] - 1s 95ms/step - loss: 2391.3013 - mae: 44.8108 - val_loss: 2120.4780 - val_mae: 42.0156
# Epoch 2/80
# 4/4 [==============================] - 0s 15ms/step - loss: 2377.2351 - mae: 44.6498 - val_loss: 2103.5779 - val_mae: 41.8116
# Epoch 3/80
# 4/4 [==============================] - 0s 16ms/step - loss: 2357.4575 - mae: 44.4205 - val_loss: 2079.0168 - val_mae: 41.5133
# Epoch 4/80
# 4/4 [==============================] - 0s 17ms/step - loss: 2328.3777 - mae: 44.0775 - val_loss: 2042.4559 - val_mae: 41.0642
# Epoch 65/80
# 4/4 [==============================] - 0s 17ms/step - loss: 95.1636 - mae: 7.6756 - val_loss: 99.1173 - val_mae: 7.8548
# Epoch 66/80
# 4/4 [==============================] - 0s 17ms/step - loss: 94.6793 - mae: 7.6049 - val_loss: 99.9116 - val_mae: 7.8210
# Epoch 67/80
# 4/4 [==============================] - 0s 18ms/step - loss: 94.2428 - mae: 7.5968 - val_loss: 97.4292 - val_mae: 7.8300
# Epoch 68/80
# 4/4 [==============================] - 0s 18ms/step - loss: 93.4476 - mae: 7.6208 - val_loss: 96.6528 - val_mae: 7.8536
# Epoch 69/80
# 4/4 [==============================] - 0s 16ms/step - loss: 93.6984 - mae: 7.6769 - val_loss: 96.4986 - val_mae: 7.8343
# Epoch 70/80
# 4/4 [==============================] - 0s 18ms/step - loss: 92.7669 - mae: 7.5994 - val_loss: 98.6471 - val_mae: 7.7644
# Epoch 71/80
# 4/4 [==============================] - 0s 17ms/step - loss: 92.6651 - mae: 7.5430 - val_loss: 97.1900 - val_mae: 7.7493
# Epoch 72/80
# 4/4 [==============================] - 0s 17ms/step - loss: 91.6642 - mae: 7.5393 - val_loss: 95.3197 - val_mae: 7.7902
# Epoch 73/80
# 4/4 [==============================] - 0s 17ms/step - loss: 91.6658 - mae: 7.5856 - val_loss: 94.6700 - val_mae: 7.7439
# Epoch 74/80
# 4/4 [==============================] - 0s 17ms/step - loss: 90.7919 - mae: 7.5181 - val_loss: 95.7468 - val_mae: 7.6575
# Epoch 75/80
# 4/4 [==============================] - 0s 18ms/step - loss: 90.6560 - mae: 7.4707 - val_loss: 94.9752 - val_mae: 7.6436
# Epoch 76/80
# 4/4 [==============================] - 0s 18ms/step - loss: 90.3557 - mae: 7.5019 - val_loss: 93.4359 - val_mae: 7.6934
# Epoch 77/80
# 4/4 [==============================] - 0s 16ms/step - loss: 89.8251 - mae: 7.4907 - val_loss: 94.3113 - val_mae: 7.6207
# Epoch 78/80
# 4/4 [==============================] - 0s 18ms/step - loss: 89.3544 - mae: 7.4361 - val_loss: 94.6759 - val_mae: 7.6164
# Epoch 79/80
# 4/4 [==============================] - 0s 18ms/step - loss: 89.1365 - mae: 7.4286 - val_loss: 94.2506 - val_mae: 7.6280
# Epoch 80/80
# 4/4 [==============================] - 0s 19ms/step - loss: 88.6806 - mae: 7.4219 - val_loss: 93.1828 - val_mae: 7.6478

# %%
#testing
model4_pred = model4.predict(x_test)

# %% [markdown]
# #### 8.4.1 Model evaluation

# %%
#mean absolute error
mae4 = mean_absolute_error(y_test, model4_pred)
mae4
# Out:
# 7.647835581557556

# %% [markdown]
# - **We can notice that at this stage, making the model deeper will not make a huge difference.**

# %%
#mean squared error
mse4 = mean_squared_error(y_test, model4_pred)
mse4
# Out:
# 93.18276875139384

# %%
plt.scatter(y_test, model4_pred)
plt.plot(y_test, y_test, "r")

# %%
model4.evaluate(x_test, y_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 93.1828 - mae: 7.6478
# [93.1827621459961, 7.647835731506348]
